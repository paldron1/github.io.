# %%
pwd
# Out:
# 'C:\\Users\\Owen Brown\\Desktop\\face_detection\\Touch_Free\\Touch_Free'

# %%
import pickle

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
import cv2


data_dict = pickle.load(open('data.pickle', 'rb'))

# %%
data = np.asarray(data_dict['data'])
labels = np.asarray(data_dict['labels'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = np.asarray(data_dict['data'])
#       2 labels = np.asarray(data_dict['labels'])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (289,) + inhomogeneous part.

# %%
# Define the desired shape for the images (e.g., 128x128)
desired_shape = (128, 128)

# Initialize an empty list to store resized images
resized_images = []

# Iterate through the data (JPG images) and resize them
for img in data_dict['data']:
    # Convert the image (which might be in array format) into a NumPy array
    img_array = np.array(img)

    # Resize the image to the desired shape
    resized_img = cv2.resize(img_array, desired_shape)

    # Append the resized image to the list
    resized_images.append(resized_img)

# Convert the resized image list into a NumPy array
data = np.asarray(resized_images)

# %%
labels = np.asarray(data_dict['labels'])

# %%
from sklearn.model_selection import train_test_split

# Perform the train/test split (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)

# %%
import cv2

# %%
import cv2
import numpy as np
import pickle
from sklearn.model_selection import train_test_split

# Load the data
data_dict = pickle.load(open('./data.pickle', 'rb'))

# Define the desired shape for all images (e.g., 128x128)
desired_shape = (128, 128)

# Resize all images to the desired shape
resized_images = []
for img in data_dict['data']:
    img_array = np.array(img)
    resized_img = cv2.resize(img_array, desired_shape)
    resized_images.append(resized_img)

# Convert the resized images to a NumPy array
data = np.asarray(resized_images)

# Ensure images are in the format (height, width, channels)
if len(data.shape) == 3:  # If images are grayscale, add the channel dimension
    data = np.expand_dims(data, axis=-1)

# Convert labels to a NumPy array
labels = np.asarray(data_dict['labels'])

# Check data shapes before splitting
print(f"Data shape: {data.shape}")
print(f"Labels shape: {labels.shape}")

# Perform the train/test split (80% train, 20% test)
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)

# Check the shapes of the resulting splits
print(f"x_train shape: {x_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Data shape: (289, 128, 128, 1)
# Labels shape: (289,)
# x_train shape: (231, 128, 128, 1)
# x_test shape: (58, 128, 128, 1)
# y_train shape: (231,)
# y_test shape: (58,)

# %%
# Flatten the images: reshape from (samples, 128, 128, 1) to (samples, 128*128)
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

print("x_train shape after flattening:", x_train_flat.shape)  # Should be (231, 16384)
print("x_test shape after flattening:", x_test_flat.shape)    # Should be (58, 16384)
# Out:
# x_train shape after flattening: (231, 16384)
# x_test shape after flattening: (58, 16384)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle

# Initialize the RandomForestClassifier
model = RandomForestClassifier()

# Fit the model on the training data
model.fit(x_train_flat, y_train)

# Predict on the test data
y_predict = model.predict(x_test_flat)

# Calculate the accuracy score
score = accuracy_score(y_test, y_predict)
print('{}% of samples were classified correctly!'.format(score * 100))

# Save the trained model using pickle
with open('model.p', 'wb') as f:
    pickle.dump({'model': model}, f)
# Out:
# 100.0% of samples were classified correctly!

# %%
import pickle

import cv2
import mediapipe as mp
import numpy as np

model_dict = pickle.load(open('./model.p', 'rb'))
model = model_dict['model']

cap = cv2.VideoCapture(2)

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

labels_dict = {0: 'A', 1: 'B', 2: 'L'}
while True:

    data_aux = []
    x_ = []
    y_ = []

    ret, frame = cap.read()

    H, W, _ = frame.shape

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(frame_rgb)
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                frame,  # image to draw
                hand_landmarks,  # model output
                mp_hands.HAND_CONNECTIONS,  # hand connections
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

        for hand_landmarks in results.multi_hand_landmarks:
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y

                x_.append(x)
                y_.append(y)

            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

        x1 = int(min(x_) * W) - 10
        y1 = int(min(y_) * H) - 10

        x2 = int(max(x_) * W) - 10
        y2 = int(max(y_) * H) - 10

        prediction = model.predict([np.asarray(data_aux)])

        predicted_character = labels_dict[int(prediction[0])]

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
        cv2.putText(frame, predicted_character, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 0, 0), 3,
                    cv2.LINE_AA)

    cv2.imshow('frame', frame)
    cv2.waitKey(1)


cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 27
#      23 y_ = []
#      25 ret, frame = cap.read()
# ---> 27 H, W, _ = frame.shape
#      29 frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      31 results = hands.process(frame_rgb)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# # cap = cv2.VideoCapture(1)  # You may need to change the index (0 for default camera)
#
# # Check if the camera opened successfully
# if not cap.isOpened():
#     print("Error: Could not open camera.")
#     exit()
#
# while True:
#     ret, frame = cap.read()
#
#     # If ret is False, the frame was not captured
#     if not ret:
#         print("Error: Failed to capture frame.")
#         break
#
#     # Proceed only if the frame was captured
#     if frame is not None:
#         H, W, _ = frame.shape  # Correct usage: no parentheses after shape
#         print(f"Frame captured with dimensions: {H}x{W}")
#         # Your further processing (e.g., color conversion, hand detection) here
#     else:
#         print("Error: Frame is None.")
#         break
#
#     if cv2.waitKey(25) == ord('q'):
#         break
#
# cap.release()
# cv2.destroyAllWindows()

# %%
import pickle

import cv2
import mediapipe as mp
import numpy as np

model_dict = pickle.load(open('model.p', 'rb'))
model = model_dict['model']

cap = cv2.VideoCapture(2)

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

labels_dict = {0: 'A', 1: 'B', 2: 'L'}
while True:

    data_aux = []
    x_ = []
    y_ = []

    ret, frame = cap.read()

    H, W, _ = frame.shape

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(frame_rgb)
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                frame,  # image to draw
                hand_landmarks,  # model output
                mp_hands.HAND_CONNECTIONS,  # hand connections
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

        for hand_landmarks in results.multi_hand_landmarks:
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y

                x_.append(x)
                y_.append(y)

            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

        x1 = int(min(x_) * W) - 10
        y1 = int(min(y_) * H) - 10

        x2 = int(max(x_) * W) - 10
        y2 = int(max(y_) * H) - 10

        prediction = model.predict([np.asarray(data_aux)])

        predicted_character = labels_dict[int(prediction[0])]

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
        cv2.putText(frame, predicted_character, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 0, 0), 3,
                    cv2.LINE_AA)

    cv2.imshow('frame', frame)
    cv2.waitKey(1)


cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 27
#      23 y_ = []
#      25 ret, frame = cap.read()
# ---> 27 H, W, _ = frame.shape
#      29 frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      31 results = hands.process(frame_rgb)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam")

# %%
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)
# Out:
# True

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break
        cv2.imshow("Webcam", frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
import pickle
import cv2
import mediapipe as mp
import numpy as np

# Load the trained model
model_dict = pickle.load(open('model.p', 'rb'))
model = model_dict['model']

# Initialize webcam capture
cap = cv2.VideoCapture(0)  # Start with camera index 0, change if needed

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam")
    exit()

# Initialize Mediapipe for hand tracking
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
# Set static_image_mode=False for continuous real-time detection
hands = mp_hands.Hands(static_image_mode=False, min_detection_confidence=0.3)

# Labels dictionary for predictions
labels_dict = {0: 'A', 1: 'B', 2: 'L'}

while True:
    data_aux = []
    x_ = []
    y_ = []

    # Capture frame from the webcam
    ret, frame = cap.read()

    # If the frame is not successfully captured, break the loop
    if not ret:
        print("Failed to grab frame")
        break

    # Get frame dimensions and ensure frame isn't empty
    H, W, _ = frame.shape

    # Convert BGR to RGB for Mediapipe
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame with Mediapipe to detect hands
    results = hands.process(frame_rgb)

    # If hand landmarks are detected
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Draw landmarks on the frame
            mp_drawing.draw_landmarks(
                frame, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

            # Extract landmark coordinates
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                x_.append(x)
                y_.append(y)

            # Prepare data for model prediction
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

            # Define bounding box coordinates around the hand
            x1 = int(min(x_) * W) - 10
            y1 = int(min(y_) * H) - 10
            x2 = int(max(x_) * W) - 10
            y2 = int(max(y_) * H) - 10

            # Make prediction using the model and handle any KeyError
            try:
                prediction = model.predict([np.asarray(data_aux)])
                predicted_character = labels_dict[int(prediction[0])]
            except KeyError:
                predicted_character = "Unknown"

            # Draw bounding box and label on the frame
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
            cv2.putText(frame, predicted_character, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 0, 0), 3, cv2.LINE_AA)

    # Display the frame
    cv2.imshow('frame', frame)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Owen Brown\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 81
#      79 # Make prediction using the model and handle any KeyError
#      80 try:
# ---> 81     prediction = model.predict([np.asarray(data_aux)])
#      82     predicted_character = labels_dict[int(prediction[0])]
#      83 except KeyError:
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:905, in ForestClassifier.predict(self, X)
#     884 def predict(self, X):
#     885     """
#     886     Predict class for X.
#     887
#    (...)
# ...

# %%
import pickle
import cv2
import mediapipe as mp
import numpy as np
import joblib


model_dict =joblib.load('hand_pose_random_forest_model.pkl')  # Load the model
model = model_dict['model']

cap = cv2.VideoCapture(0)  # Use the correct camera index

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

labels_dict = {0: 'A', 1: 'B', 2: 'L'}
while True:

    data_aux = []
    x_ = []
    y_ = []

    ret, frame = cap.read()
    
    # Check if the frame was captured correctly
    if not ret or frame is None:
        print("Failed to capture frame")
        break

    H, W, _ = frame.shape

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(frame_rgb)
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                frame,  # image to draw
                hand_landmarks,  # model output
                mp_hands.HAND_CONNECTIONS,  # hand connections
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

        for hand_landmarks in results.multi_hand_landmarks:
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y

                x_.append(x)
                y_.append(y)

            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

        x1 = int(min(x_) * W) - 10
        y1 = int(min(y_) * H) - 10

        x2 = int(max(x_) * W) - 10
        y2 = int(max(y_) * H) - 10

        prediction = model.predict([np.asarray(data_aux)])

        predicted_character = labels_dict[int(prediction[0])]

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
        cv2.putText(frame, predicted_character, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 0, 0), 3,
                    cv2.LINE_AA)

    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       5 import joblib
#       8 model_dict =joblib.load('hand_pose_random_forest_model.pkl')  # Load the model
# ----> 9 model = model_dict['model']
#      11 cap = cv2.VideoCapture(0)  # Use the correct camera index
#      13 mp_hands = mp.solutions.hands
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_base.py:158, in BaseEnsemble.__getitem__(self, index)
#     156 def __getitem__(self, index):
#     157     """Return the index'th estimator in the ensemble."""
# --> 158     return self.estimators_[index]
#
# TypeError: list indices must be integers or slices, not str

# %%
# Assuming the model expects 16384 features
required_features = 16384

# Check the current length of data_aux
if len(data_aux) < required_features:
    # Pad the data with zeros
    data_aux += [0] * (required_features - len(data_aux))

# Convert data_aux to a numpy array and reshape it for prediction
data_aux = np.asarray(data_aux).reshape(1, -1)

# Perform prediction
prediction = model.predict(data_aux)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 required_features = 16384
#       4 # Check the current length of data_aux
# ----> 5 if len(data_aux) < required_features:
#       6     # Pad the data with zeros
#       7     data_aux += [0] * (required_features - len(data_aux))
#       9 # Convert data_aux to a numpy array and reshape it for prediction
#
# NameError: name 'data_aux' is not defined

# %%
# Check the current length of data_aux
if len(data_aux) < required_features:
    # Pad the data with zeros
    data_aux += [0] * (required_features - len(data_aux))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Check the current length of data_aux
# ----> 2 if len(data_aux) < required_features:
#       3     # Pad the data with zeros
#       4     data_aux += [0] * (required_features - len(data_aux))
#
# NameError: name 'data_aux' is not defined

# %%
import pickle
import cv2
import mediapipe as mp
import numpy as np

model_dict = pickle.load(open('model.p', 'rb'))
model = model_dict['model']

cap = cv2.VideoCapture(1)  # Use the correct camera index

mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)

labels_dict = {0: 'Start_OPC1', 1: 'Pause_OPC1', 2: 'Stop_OPC1'}
while True:

    data_aux = []
    x_ = []
    y_ = []

    ret, frame = cap.read()
    
    # Check if the frame was captured correctly
    if not ret or frame is None:
        print("Failed to capture frame")
        break

    H, W, _ = frame.shape

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = hands.process(frame_rgb)
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                frame,  # image to draw
                hand_landmarks,  # model output
                mp_hands.HAND_CONNECTIONS,  # hand connections
                mp_drawing_styles.get_default_hand_landmarks_style(),
                mp_drawing_styles.get_default_hand_connections_style())

        for hand_landmarks in results.multi_hand_landmarks:
            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y

                x_.append(x)
                y_.append(y)

            for i in range(len(hand_landmarks.landmark)):
                x = hand_landmarks.landmark[i].x
                y = hand_landmarks.landmark[i].y
                data_aux.append(x - min(x_))
                data_aux.append(y - min(y_))

        x1 = int(min(x_) * W) - 10
        y1 = int(min(y_) * H) - 10

        x2 = int(max(x_) * W) - 10
        y2 = int(max(y_) * H) - 10

        # Padding data_aux to ensure it has the required number of features
        required_features = 16384  # As the model expects 16384 features

        # If the extracted features are fewer than expected, pad with zeros
        if len(data_aux) < required_features:
            data_aux += [0] * (required_features - len(data_aux))
        
        # Convert data_aux to a numpy array and reshape it for prediction
        data_aux = np.asarray(data_aux).reshape(1, -1)

        # Perform prediction
        prediction = model.predict(data_aux)

        predicted_character = labels_dict[int(prediction[0])]

        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 0), 4)
        cv2.putText(frame, predicted_character, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 0, 0), 3,
                    cv2.LINE_AA)

    cv2.imshow('frame', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Owen Brown\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# C:\Users\Owen Brown\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# C:\Users\Owen Brown\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ...
